# %% [markdown]
# # Table of Contents
#
# 01. Import Libraries
# 02. Import Data
# 03. Exercise 4.7
# 04. Task 4.7

# %% [markdown]
# # 01. Import Libraries

# %%
#import libraries - Task 4.7
import pandas as pd
import numpy as np
import os

# %% [markdown]
# # 02. Import Data

# %%
path = r'C:\Users\Cathy\2022 Instacart Basket Analysis'

# %%
df_orders_products_merged = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_merged.pkl'))

# %% [markdown]
# # 03. Exercise 4.7

# %%
df_orders_products_merged.shape
# Out:
# (32434212, 14)

# %%
#subset for memory conservation
df = df_orders_products_merged[:1000000]

# %%
df.shape
# Out:
# (1000000, 15)

# %%
df.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2398795        1             2                   3                  7
# 2    473747        1             3                   3                 12
# 3   2254736        1             4                   4                  7
# 4    431534        1             5                   4                 15
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN         196                  1          0
# 1                    15.0         196                  1          1
# 2                    21.0         196                  1          1
# 3                    29.0         196                  1          1
# 4                    28.0         196                  1          1
#
#   product_name  aisle_id  department_id  prices _merge        price_range
# ...

# %%
#define price _label row
def price_label(row):

  if row['prices'] <= 5:
    return 'Low-range product'
  elif (row['prices'] > 5) and (row['prices'] <= 15):
    return 'Mid-range product'
  elif row['prices'] > 15:
    return 'High range'
  else: return 'Not enough data'

# %%
df['price_range'] = df.apply(price_label, axis=1)
# Out:
# C:\Users\Cathy\AppData\Local\Temp\ipykernel_3492\2848743372.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price_range'] = df.apply(price_label, axis=1)

# %%
df['price_range'].value_counts(dropna = False)
# Out:
# Mid-range product    756450
# Low-range product    243550
# Name: price_range, dtype: int64

# %%
df['prices'].max()
# Out:
# 14.8

# %%
#if statements with (loc)
df_orders_products_merged.loc[df_orders_products_merged['prices'] > 15, 'price_range_loc'] = 'High-range product'

# %%
df_orders_products_merged.loc[(df_orders_products_merged['prices'] <= 15) & (df_orders_products_merged['prices'] > 5), 'price_range_loc'] = 'Mid-range product'

# %%
df_orders_products_merged.loc[df_orders_products_merged['prices'] <= 5, 'price_range_loc'] = 'Low-range product'

# %%
df_orders_products_merged['price_range_loc'].value_counts(dropna = False)
# Out:
# Mid-range product     21890146
# Low-range product     10126384
# High-range product      417682
# Name: price_range_loc, dtype: int64

# %%
#find busiest day of week. 0=Saturday
df_orders_products_merged['orders_day_of_week'].value_counts(dropna = False)
# Out:
# 0    6209632
# 1    5665830
# 6    4500246
# 2    4217766
# 5    4209449
# 3    3844096
# 4    3787193
# Name: orders_day_of_week, dtype: int64

# %%
#if statements with for-loops
result = []

for value in df_orders_products_merged["orders_day_of_week"]:
  if value == 0:
    result.append("Busiest day")
  elif value == 4:
    result.append("Least busy")
  else:
    result.append("Regularly busy")

# %%
result
# Out:
# ['Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
# ...

# %%
#add result definition to merged data frame
df_orders_products_merged['busiest_day'] = result

# %%
df_orders_products_merged['busiest_day'].value_counts(dropna = False)
# Out:
# Regularly busy    22437387
# Busiest day        6209632
# Least busy         3787193
# Name: busiest_day, dtype: int64

# %% [markdown]
# # 04. Task 4.7

# %%
#Step 2. Saturday(0) and Sunday(1) are busiest. Tuesday(3) and Wednesday(4) are slowest.
result = []

for value in df_orders_products_merged["orders_day_of_week"]:
  if value == 0:
    result.append("Busiest days")
  elif value == 1:
    result.append("Busiest days")
  elif value == 3:
    result.append("Least busy")
  elif value == 4:
    result.append("Least busy")
  else:
    result.append("Regularly busy")

# %%
df_orders_products_merged['busiest_days'] = result

# %%
#Step 3
df_orders_products_merged['busiest_days'].value_counts(dropna = False)
# Out:
# Regularly busy    12927461
# Busiest days      11875462
# Least busy         7631289
# Name: busiest_days, dtype: int64

# %% [markdown]
# Step 3 Observations:Sunday and Saturday appear to have been added together, as well as Tuesday and Wednesday. I have noticed, though that my value counts are different from the exercise values.

# %%
# Step 4
df_orders_products_merged['order_hour_of_day'].value_counts(dropna = False)
# Out:
# 10    2764390
# 11    2738585
# 14    2691563
# 15    2664522
# 13    2663272
# 12    2620800
# 16    2537469
# 9     2456661
# 17    2089452
# 8     1719952
# 18    1637922
# 19    1259382
# 20     977017
# 7      891928
# 21     796362
# 22     634737
# 23     402612
# 6      290770
# 0      218942
# 1      115786
# 5       88057
# 2       69431
# 4       53283
# 3       51317
# Name: order_hour_of_day, dtype: int64

# %%
df_orders_products_merged['order_hour_of_day'].describe()
# Out:
# count    3.243421e+07
# mean     1.342500e+01
# std      4.246351e+00
# min      0.000000e+00
# 25%      1.000000e+01
# 50%      1.300000e+01
# 75%      1.600000e+01
# max      2.300000e+01
# Name: order_hour_of_day, dtype: float64

# %%
#this first attempt crashed computer. using (loc) on next attempt. Adjusted 'Fewest Orders' on (loc) format to include >=21
def busy_periods(row):

  if row['order_hour_of_day'] <= 7:
    return 'Fewest Orders'
  elif (row['order_hour_of_day'] >= 18) and (row['order_hour_of_day'] <= 20):
    return 'Average Orders'
  elif row(['order_hour_of_day'] >=8) and (row['order_hour_of_day'] <=17):
    return 'Most Orders'
  else: return 'Not enough data'

# %%
df_orders_products_merged.loc[df_orders_products_merged['order_hour_of_day'] <= 7, 'busiest_period_of_day'] = 'Fewest Orders'

# %%
df_orders_products_merged.loc[df_orders_products_merged['order_hour_of_day'] >= 21, 'busiest_period_of_day'] = 'Fewest Orders'

# %%
df_orders_products_merged.loc[(df_orders_products_merged['order_hour_of_day'] <= 20) & (df_orders_products_merged['order_hour_of_day'] >= 18), 'busiest_period_of_day'] = 'Average Orders'

# %%
df_orders_products_merged.loc[(df_orders_products_merged['order_hour_of_day'] <= 17) & (df_orders_products_merged['order_hour_of_day'] >= 8), 'busiest_period_of_day'] = 'Most Orders'

# %%
#Step 4
df_orders_products_merged['busiest_period_of_day'].value_counts(dropna = False)
# Out:
# Most Orders       24946666
# Average Orders     3874321
# Fewest Orders      3613225
# Name: busiest_period_of_day, dtype: int64

# %%
#check for missing values due to NaN on new column
df_orders_products_merged.isnull().sum()
# Out:
# order_id                        0
# user_id                         0
# order_number                    0
# orders_day_of_week              0
# order_hour_of_day               0
# days_since_prior_order    2078084
# product_id                      0
# add_to_cart_order               0
# reordered                       0
# product_name                28171
# aisle_id                        0
# department_id                   0
# prices                          0
# _merge                          0
# price_range_loc                 0
# busiest_days                    0
# busiest_period_of_day           0
# dtype: int64

# %% [markdown]
# No missing values in order_hour_of_day but NaN values on new busiest_period_of_day column??

# %%
df_orders_products_merged.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2398795        1             2                   3                  7
# 2    473747        1             3                   3                 12
# 3   2254736        1             4                   4                  7
# 4    431534        1             5                   4                 15
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN         196                  1          0
# 1                    15.0         196                  1          1
# 2                    21.0         196                  1          1
# 3                    29.0         196                  1          1
# 4                    28.0         196                  1          1
#
#   product_name  aisle_id  department_id  prices _merge    price_range_loc  \
# ...

# %%
#Step 7: export
df_orders_products_merged.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'orders_products_merged_derived.pkl'))
